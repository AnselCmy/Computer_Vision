# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np
import re

# %%
plt.figure(figsize=(10, 10))
img_list = os.listdir("../img/threshold")[1:]
rows = len(img_list)//6+1
for idx in range(len(img_list)):
    plt.subplot(rows, 6, idx+1)
    img = plt.imread("../img/GLCM/"+img_list[idx])
    plt.axis("off")
    plt.title(img_list[idx])
    plt.imshow(img)

# %%
file = open('../img/threshold/threshold_13_3.pixel.txt')  
data = file.read()[1: -1]
data = re.split(';\n ', data)
data = [[int(i) for i in d.split(', ')] for d in data]
data = np.array(data)
# for h in data:
#     for w in h:
#         print("%d " % w, end='')
#     print('\n')
print(data)
# Out:
# [[255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0   0 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255 255   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0 255 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255   0 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255   0 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255   0   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255   0]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0   0 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0 255 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0   0 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]
#  [  0 255 255 255 255 255   0   0 255 255 255 255 255 255   0   0   0   0
#     0   0 255 255 255 255 255 255 255 255 255 255]]

# %%
data[0, 4]
# Out:
# 0
